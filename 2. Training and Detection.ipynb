# I0802 14:12:55.810893  9756 efficientnet_model.py:147] round_filter input=112 output=200
# I0802 14:12:55.810893  9756 efficientnet_model.py:147] round_filter input=192 output=344
# I0802 14:12:57.203673  9756 efficientnet_model.py:147] round_filter input=192 output=344
# I0802 14:12:57.203673  9756 efficientnet_model.py:147] round_filter input=320 output=576
# I0802 14:12:57.698879  9756 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0802 14:12:57.792638  9756 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0802 14:12:57.917651  9756 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0802 14:12:57.917651  9756 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0802 14:12:57.917651  9756 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 8
# I0802 14:12:57.917651  9756 efficientnet_model.py:147] round_filter input=32 output=64
# I0802 14:12:57.933278  9756 efficientnet_model.py:147] round_filter input=32 output=64
# I0802 14:12:57.933278  9756 efficientnet_model.py:147] round_filter input=16 output=32
# I0802 14:12:58.233592  9756 efficientnet_model.py:147] round_filter input=16 output=32
# I0802 14:12:58.233592  9756 efficientnet_model.py:147] round_filter input=24 output=48
# I0802 14:12:58.841276  9756 efficientnet_model.py:147] round_filter input=24 output=48
# I0802 14:12:58.841276  9756 efficientnet_model.py:147] round_filter input=40 output=80
# I0802 14:12:59.689596  9756 efficientnet_model.py:147] round_filter input=40 output=80
# I0802 14:12:59.689596  9756 efficientnet_model.py:147] round_filter input=80 output=160
# I0802 14:13:00.623414  9756 efficientnet_model.py:147] round_filter input=80 output=160
# I0802 14:13:00.623414  9756 efficientnet_model.py:147] round_filter input=112 output=224
# I0802 14:13:01.686030  9756 efficientnet_model.py:147] round_filter input=112 output=224
# I0802 14:13:01.686030  9756 efficientnet_model.py:147] round_filter input=192 output=384
# I0802 14:13:03.477982  9756 efficientnet_model.py:147] round_filter input=192 output=384
# I0802 14:13:03.477982  9756 efficientnet_model.py:147] round_filter input=320 output=640
# I0802 14:13:04.268415  9756 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0802 14:13:04.372692  9756 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.73s
# I0802 14:13:04.531481  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.73s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0802 14:13:04.547108  9756 test_util.py:2102] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 43.545s
#
# OK (skipped=1)

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# apache-beam                   2.31.0
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# avro-python3                  1.9.2.1
# backcall                      0.2.0
# bleach                        3.3.1
# cachetools                    4.2.2
# certifi                       2021.5.30
# cffi                          1.14.6
# charset-normalizer            2.0.4
# colorama                      0.4.4
# contextlib2                   21.6.0
# crcmod                        1.7
# cycler                        0.10.0
# Cython                        0.29.24
# decorator                     5.0.7
# defusedxml                    0.7.1
# dill                          0.3.1.1
# dm-tree                       0.1.6
# docopt                        0.6.2
# entrypoints                   0.3
# fastavro                      1.4.4
# flatbuffers                   1.12
# future                        0.18.2
# gast                          0.4.0
# gin-config                    0.4.0
# google-api-core               1.31.1
# google-api-python-client      2.15.0
# google-auth                   1.34.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.5
# google-cloud-bigquery         1.21.0
# google-cloud-core             1.7.2
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.53.0
# grpcio                        1.34.1
# h5py                          3.1.0
# hdfs                          2.6.0
# httplib2                      0.19.1
# idna                          3.2
# ipykernel                     5.5.3
# ipython                       7.23.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.18.0
# Jinja2                        3.0.1
# joblib                        1.0.1
# jsonschema                    3.2.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.7.1
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.0
# kaggle                        1.5.12
# keras-nightly                 2.5.0.dev2021032900
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# lvis                          0.5.3
# lxml                          4.6.3
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.4.2
# matplotlib-inline             0.1.2
# mistune                       0.8.4
# nbclient                      0.5.3
# nbconvert                     6.1.0
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# notebook                      6.4.0
# numpy                         1.19.5
# oauth2client                  4.1.3
# oauthlib                      3.1.1
# object-detection              0.1
# opencv-contrib-python         4.5.3.56
# opencv-python                 4.5.3.56
# opencv-python-headless        4.5.3.56
# opt-einsum                    3.3.0
# packaging                     21.0
# pandas                        1.3.1
# pandocfilters                 1.4.3
# parso                         0.8.2
# pickleshare                   0.7.5
# Pillow                        8.3.1
# pip                           21.2.2
# portalocker                   2.0.0
# prometheus-client             0.11.0
# promise                       2.3
# prompt-toolkit                3.0.18
# protobuf                      3.17.3
# psutil                        5.8.0
# py-cpuinfo                    8.0.0
# pyarrow                       4.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.2
# pycparser                     2.20
# pydot                         1.4.2
# Pygments                      2.9.0
# pymongo                       3.12.0
# pyparsing                     2.4.7
# PyQt5                         5.15.4
# PyQt5-Qt5                     5.15.2
# PyQt5-sip                     12.8.1
# pyrsistent                    0.18.0
# python-dateutil               2.8.1
# python-slugify                5.0.2
# pytz                          2021.1
# pywin32                       300
# pywinpty                      1.1.3
# PyYAML                        5.4.1
# pyzmq                         22.0.3
# qtconsole                     5.1.1
# QtPy                          1.9.0
# requests                      2.26.0
# requests-oauthlib             1.3.0
# rsa                           4.7.2
# sacrebleu                     1.5.1
# scikit-learn                  0.24.2
# scipy                         1.7.1
# Send2Trash                    1.7.1
# sentencepiece                 0.1.96
# seqeval                       1.2.2
# setuptools                    49.2.1
# six                           1.15.0
# tensorboard                   2.5.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.5.0
# tensorflow-addons             0.13.0
# tensorflow-datasets           4.4.0
# tensorflow-estimator          2.5.0
# tensorflow-hub                0.12.0
# tensorflow-metadata           1.2.0
# tensorflow-model-optimization 0.6.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# text-unidecode                1.3
# tf-models-official            2.5.1
# tf-slim                       1.1.0
# threadpoolctl                 2.2.0
# tornado                       6.1
# tqdm                          4.62.0
# traitlets                     5.0.5
# typeguard                     2.12.1
# typing-extensions             3.7.4.3
# uritemplate                   3.0.1
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      2.0.1
# wget                          3.2
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wrapt                         1.12.1

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
#    !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20518283 / 20518283        1 file(s) moved.

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'one', 'id':1}, {'name':'two', 'id':2}, {'name':'three', 'id':3}, {'name':'four', 'id':4}, {'name':'five', 'id':5}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned_2 --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned_2\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'four.b30fbff3-f3a4-11eb-9024-54e1ad282796.jpg')

# %%
IMAGE_PATH
# Out:
# 'Tensorflow\\workspace\\images\\test\\four.b13fc99c-f3a4-11eb-96e2-54e1ad282796.jpg'

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.7,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --output_directory=Tensorflow\workspace\models\my_ssd_mobnet_tuned\export

# %%
# !{command}
# Out:
# 2021-08-03 01:45:57.227176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:45:57.227500: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-08-03 01:46:00.952442: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-08-03 01:46:01.602792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:46:01.603816: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:46:01.604553: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-08-03 01:46:01.605297: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-08-03 01:46:01.606002: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2021-08-03 01:46:01.606687: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2021-08-03 01:46:01.607407: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-08-03 01:46:01.608072: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-08-03 01:46:01.608834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-08-03 01:46:01.609012: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:46:01.609940: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-03 01:46:01.610706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:46:01.610962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# WARNING:tensorflow:From F:\My_ML_Projects\Ex\Object Detection Ex\Ex1\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0803 01:46:02.059418  4940 deprecation.py:596] From F:\My_ML_Projects\Ex\Object Detection Ex\Ex1\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002C46BD9A1F0>, because it is not built.
# W0803 01:46:19.961928  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002C46BD9A1F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000002C46BD9A970>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000002C46BD9A970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000
>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D0FB820>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D0FB820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D0FBB80>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D0FBB80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D8C4CD0>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D8C4CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D8C4B80>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D8C4B80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D896730>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D896730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D8966D0>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D8966D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D896B50>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D896B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D896970>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D896970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D0BBEE0>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002C46D0BBEE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D0BBB50>, because it is not built.
# W0803 01:46:20.086944  4940 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002C46D0BBB50>, because it is not built.
# 2021-08-03 01:46:28.657490: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0803 01:46:44.465735  4940 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# F:\My_ML_Projects\Ex\Object Detection Ex\Ex1\TFODCourse\tfod\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0803 01:46:49.039382  4940 save.py:1239] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\saved_model\assets
# I0803 01:46:50.375302  4940 builder_impl.py:774] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\pipeline.config
# I0803 01:46:51.342975  4940 config_util.py:253] Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.8.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (2.5.0)
# Requirement already satisfied: six<2,>=1.12.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: google-pasta~=0.2 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: tensorboard~=2.5 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: h5py~=3.1.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: numpy~=1.19.2 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: grpcio~=1.34.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: typing-extensions~=3.7.4 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: gast==0.4.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: requests<3,>=2.21.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (49.2.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.34.0)
# Requirement already satisfied: werkzeug>=0.11.15 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.1)
# Requirement already satisfied: markdown>=2.6.8 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.5)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\my_ml_projects\ex\object detection ex\ex1\tfodcourse\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Installing collected packages: tensorflowjs
# Successfully installed tensorflowjs-3.8.0

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\saved_model Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfjsexport

# %%
# !{command}
# Out:
# Writing weight file Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfjsexport\model.json...
# 2021-08-03 01:47:21.359312: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:47:21.359759: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-08-03 01:47:26.244546: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-08-03 01:47:26.822173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:47:26.823240: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:47:26.823959: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-08-03 01:47:26.824675: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-08-03 01:47:26.825399: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2021-08-03 01:47:26.826134: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2021-08-03 01:47:26.826862: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-08-03 01:47:26.827570: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-08-03 01:47:26.828348: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-08-03 01:47:26.828616: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:47:26.829360: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-03 01:47:26.830135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:47:26.830532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-08-03 01:47:35.785438: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2021-08-03 01:47:36.031979: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2021-08-03 01:47:36.295681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:47:36.296538: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:47:37.327675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:47:37.328332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-08-03 01:47:37.328722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-08-03 01:47:37.728857: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 3904 nodes (3495), 8306 edges (7890), time = 247.269ms.
#   function_optimizer: function_optimizer did nothing. time = 3.393ms.
#
# 2021-08-03 01:47:42.040639: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   model_pruner: Graph size after: 3166 nodes (-441), 7624 edges (-441), time = 55.808ms.
#   constant_folding: Graph size after: 1568 nodes (-1598), 5774 edges (-1850), time = 191.726ms.
#   arithmetic_optimizer: Graph size after: 1584 nodes (16), 5798 edges (24), time = 35.943ms.
#   dependency_optimizer: Graph size after: 1499 nodes (-85), 1712 edges (-4086), time = 30.878ms.
#   model_pruner: Graph size after: 1499 nodes (0), 1712 edges (0), time = 13.194ms.
#   constant_folding: Graph size after: 1499 nodes (0), 1712 edges (0), time = 50.7ms.
#   arithmetic_optimizer: Graph size after: 1499 nodes (0), 1712 edges (0), time = 28.207ms.
#   dependency_optimizer: Graph size after: 1499 nodes (0), 1712 edges (0), time = 17.379ms.
#   debug_stripper: Graph size after: 1499 nodes (0), 1712 edges (0), time = 6.791ms.
#   model_pruner: Graph size after: 1497 nodes (-2), 1710 edges (-2), time = 20.557ms.
#   constant_folding: Graph size after: 1497 nodes (0), 1710 edges (0), time = 38.266ms.
#   arithmetic_optimizer: Graph size after: 1497 nodes (0), 1710 edges (0), time = 29.586ms.
#   dependency_optimizer: Graph size after: 1492 nodes (-5), 1700 edges (-10), time = 17.832ms.
#   model_pruner: Graph size after: 1492 nodes (0), 1700 edges (0), time = 12.581ms.
#   constant_folding: Graph size after: 1492 nodes (0), 1700 edges (0), time = 36.454ms.
#   arithmetic_optimizer: Graph size after: 1492 nodes (0), 1700 edges (0), time = 29.437ms.
#   dependency_optimizer: Graph size after: 1492 nodes (0), 1700 edges (0), time = 17.426ms.
#   debug_stripper: debug_stripper did nothing. time = 1.993ms.
#
# 2021-08-03 01:47:50.618894: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 1456 nodes (-112), 1360 edges (-112), time = 10.95ms.
#   constant_folding: Graph size after: 1152 nodes (-304), 1360 edges (0), time = 61.353ms.
#   arithmetic_optimizer: Graph size after: 1152 nodes (0), 1360 edges (0), time = 23.043ms.
#   dependency_optimizer: Graph size after: 1152 nodes (0), 1360 edges (0), time = 13.38ms.
#   remapper: Graph size after: 1152 nodes (0), 1360 edges (0), time = 7.388ms.
#   constant_folding: Graph size after: 1152 nodes (0), 1360 edges (0), time = 30.066ms.
#   arithmetic_optimizer: Graph size after: 1152 nodes (0), 1360 edges (0), time = 23.703ms.
#   dependency_optimizer: Graph size after: 1152 nodes (0), 1360 edges (0), time = 13.662ms.

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --output_directory=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport

# %%
# !{command}
# Out:
# 2021-08-03 01:47:56.482993: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:47:56.483321: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-08-03 01:48:00.166930: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-08-03 01:48:00.185513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:48:00.186612: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:48:00.187348: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-08-03 01:48:00.188033: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-08-03 01:48:00.188838: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2021-08-03 01:48:00.189594: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2021-08-03 01:48:00.190273: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-08-03 01:48:00.190974: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-08-03 01:48:00.191758: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-08-03 01:48:00.192047: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:48:00.192880: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-03 01:48:00.193583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:00.193818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-08-03 01:48:08.239163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:08.239409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-08-03 01:48:10.149560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:10.149732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000019C216532E0>, because it is not built.
# W0803 01:48:10.798645  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000019C216532E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C216538E0>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C216538E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22D9E910>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22D9E910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22D9ED90>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22D9ED90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23091310>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23091310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23091AC0>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23091AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23091250>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23091250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23091CD0>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23091CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23091B50>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23091B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C2284ACA0>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C2284ACA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23093790>, because it is not built.
# W0803 01:48:11.001183  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000019C23093790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23093DC0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23093DC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C230934C0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C230934C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653EB0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653EB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22943CA0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22943CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23122550>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23122550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23122A90>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23122A90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23122EE0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C23122EE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C231228B0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C231228B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C231276D0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C231276D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23127730>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C23127730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653EE0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653EE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C230B3F40>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C230B3F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22FE5E80>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22FE5E80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22FE57F0>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22FE57F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22C0E160>, because it is not built.
# W0803 01:48:11.002153  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22C0E160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22C0E430>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22C0E430>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22B28730>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C22B28730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22B28EB0>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C22B28EB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653F10>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C21653F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252CFBE0>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252CFBE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D57F0>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D57F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D56D0>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D56D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D5B80>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D5B80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D5C10>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D5C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D5EB0>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D5EB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D8490>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D8490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D8E80>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D8E80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252DA130>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252DA130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2610>, because it is not built.
# W0803 01:48:11.003155  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D24F0>, because it is not built.
# W0803 01:48:11.004158  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D24F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2F40>, because it is not built.
# W0803 01:48:11.004158  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D2E50>, because it is not built.
# W0803 01:48:11.004158  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D2E50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2A30>, because it is not built.
# W0803 01:48:11.004158  5468 save_impl.py:76] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019C252D2A30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D2880>, because it is not built.
# W0803 01:48:11.004158  5468 save_impl.py:76] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000019C252D2880>, because it is not built.
# 2021-08-03 01:48:19.230221: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2021-08-03 01:48:20.822350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:20.822585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# W0803 01:48:33.323224  5468 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# F:\My_ML_Projects\Ex\Object Detection Ex\Ex1\TFODCourse\tfod\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0803 01:48:37.356203  5468 save.py:1239] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\assets
# I0803 01:48:38.206447  5468 builder_impl.py:774] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2021-08-03 01:48:42.146042: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:48:42.146355: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-08-03 01:48:47.374026: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-08-03 01:48:47.393647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:48:47.394706: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-03 01:48:47.395409: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-08-03 01:48:47.396093: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-08-03 01:48:47.396772: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2021-08-03 01:48:47.397486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2021-08-03 01:48:47.398231: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-08-03 01:48:47.398913: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-08-03 01:48:47.399572: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-08-03 01:48:47.399873: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:48:47.400610: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-03 01:48:47.401340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:47.401661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-08-03 01:48:57.998347: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:345] Ignored output_format.
# 2021-08-03 01:48:57.998839: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:348] Ignored drop_control_dependency.
# 2021-08-03 01:48:57.999252: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:354] Ignored change_concat_input_ranges.
# 2021-08-03 01:48:58.024840: I tensorflow/cc/saved_model/reader.cc:38] Reading SavedModel from: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2021-08-03 01:48:58.187541: I tensorflow/cc/saved_model/reader.cc:90] Reading meta graph with tags { serve }
# 2021-08-03 01:48:58.188482: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2021-08-03 01:48:58.188890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:48:58.189121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-08-03 01:48:58.590675: I tensorflow/cc/saved_model/loader.cc:206] Restoring SavedModel bundle.
# 2021-08-03 01:48:59.326002: I tensorflow/cc/saved_model/loader.cc:190] Running initialization op on SavedModel bundle at path: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2021-08-03 01:48:59.643053: I tensorflow/cc/saved_model/loader.cc:277] SavedModel load for tags { serve }; Status: success: OK. Took 1618228 microseconds.
# 2021-08-03 01:49:00.995035: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:210] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2021-08-03 01:49:02.641712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce 920MX computeCapability: 5.0
# coreClock: 0.993GHz coreCount: 2 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 13.41GiB/s
# 2021-08-03 01:49:02.642685: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-03 01:49:02.774075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-03 01:49:02.774315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-08-03 01:49:02.774483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
